# %% [markdown]
# <a href="https://colab.research.google.com/github/ahnafsayem/python_practice/blob/main/Data%20Analysis%20and%20Visualization%20Tools/02_movies_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/movies.csv")
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
#print first 4 rows

df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# 3      USD  English

# %%
#print last 4 rows

df.tail(4)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
#randomly calling few rows

df.sample(4)
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 6               Interstellar  Hollywood          2014          8.6
# 4    Thor: Love and Thunder   Hollywood          2022          6.8
# 10     It's a Wonderful Life  Hollywood          1946          8.6
#
#                    studio  budget  revenue      unit currency language
# 7       Columbia Pictures   55.00    307.1  Millions      USD  English
# 6   Warner Bros. Pictures  165.00    701.8  Millions      USD  English
# 4          Marvel Studios  250.00    670.0  Millions      USD  English
# 10          Liberty Films    3.18      3.3  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[2:6]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.imdb_rating.head(5)
# Out:
# 0    8.3
# 1    7.0
# 2    6.8
# 3    7.9
# 4    6.8
# Name: imdb_rating, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.imdb_rating)
# Out:
# pandas.core.series.Series

# %%
df.imdb_rating.min(),df.imdb_rating.max(),df.imdb_rating.mean()
# Out:
# (1.9, 9.3, 7.919444444444445)

# %%
df[(df.imdb_rating == df.imdb_rating.max()) | ((df.imdb_rating == df.imdb_rating.min()))]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df_bw = df[df.industry == 'Bollywood']
df_hw = df[df.industry == 'Hollywood']

# %%
df_bw.head(5)
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
# 23     Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 24             Bajirao Mastani   Bollywood          2015          7.2
#
#                        studio   budget   revenue       unit currency language
# 0   Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali
# 21             Yash Raj Films    400.0    2000.0   Millions      INR    Hindi
# 22         Vinod Chopra Films    550.0    4000.0   Millions      INR    Hindi
# 23         Dharma Productions    390.0    1360.0   Millions      INR    Hindi
# 24                        NaN      1.4       3.5   Billions      INR    Hindi

# %%
df_bw.imdb_rating.min(),df_bw.imdb_rating.max(),df_bw.imdb_rating.mean()
# Out:
# (1.9, 8.4, 7.656250000000001)

# %%
df_bw[df_bw.imdb_rating==df_bw.imdb_rating.max()]
# Out:
#                title   industry  release_year  imdb_rating  \
# 22          3 Idiots  Bollywood          2009          8.4
# 32         Shershaah  Bollywood          2021          8.4
# 33  K.G.F: Chapter 2  Bollywood          2022          8.4
#
#                 studio  budget  revenue      unit currency language
# 22  Vinod Chopra Films   550.0   4000.0  Millions      INR    Hindi
# 32  Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33       Hombale Films     1.0     12.5  Billions      INR  Kannada

# %%
df_hw.head(5)
# Out:
#                                          title   industry  release_year  \
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
# 5                     The Shawshank Redemption  Hollywood          1994
#
#    imdb_rating                     studio  budget  revenue      unit currency  \
# 1          7.0             Marvel Studios   200.0    954.8  Millions      USD
# 2          6.8             Marvel Studios   165.0    644.8  Millions      USD
# 3          7.9             Marvel Studios   180.0    854.0  Millions      USD
# 4          6.8             Marvel Studios   250.0    670.0  Millions      USD
# 5          9.3  Castle Rock Entertainment    25.0     73.3  Millions      USD
#
#   language
# 1  English
# 2  English
# 3  English
# 4  English
# ...

# %%
df_hw.imdb_rating.min(),df_hw.imdb_rating.max(),df_hw.imdb_rating.mean()
# Out:
# (6.8, 9.3, 8.130000000000003)

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df_new = df[["industry", "language","imdb_rating"]]
df_new.head(5)
# Out:
#     industry language  imdb_rating
# 0  Bollywood  Bengali          8.3
# 1  Hollywood  English          7.0
# 2  Hollywood  English          6.8
# 3  Hollywood  English          7.9
# 4  Hollywood  English          6.8

# %%
df[(df.release_year>=2010) & (df.release_year<=2020) ]
# Out:
#                                   title   industry  release_year  imdb_rating  \
# 2                 Thor: The Dark World   Hollywood          2013          6.8
# 3                       Thor: Ragnarok   Hollywood          2017          7.9
# 6                          Interstellar  Hollywood          2014          8.6
# 16                             Parasite  Hollywood          2019          8.5
# 17                    Avengers: Endgame  Hollywood          2019          8.4
# 18               Avengers: Infinity War  Hollywood          2018          8.4
# 19   Captain America: The First Avenger  Hollywood          2011          6.9
# 20  Captain America: The Winter Soldier  Hollywood          2014          7.8
# 24                     Bajirao Mastani   Bollywood          2015          7.2
# 27                                   PK  Bollywood          2014          8.1
# 28                                Sanju  Bollywood          2018          NaN
# ...

# %%
df.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
df[df.studio=="Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df["age"]=df["release_year"].apply(lambda x: 2024-x)
df.head(5)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   69
# 1      USD  English    2
# ...

# %%
df["profit"] = df.apply(lambda x: x["revenue"]-x["budget"],axis=1)
df.head(5)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   69  30000.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index('title', inplace=True)
df.head(5)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.loc[["The Shawshank Redemption", "3 Idiots"]] #normal location findings
# Out:
#                            industry  release_year  imdb_rating  \
# title
# The Shawshank Redemption  Hollywood          1994          9.3
# 3 Idiots                  Bollywood          2009          8.4
#
#                                              studio  budget  revenue  \
# title
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
# 3 Idiots                         Vinod Chopra Films   550.0   4000.0
#
#                               unit currency language  age  profit
# title
# The Shawshank Redemption  Millions      USD  English   30    48.3
# 3 Idiots                  Millions      INR    Hindi   15  3450.0

# %%
df.iloc[0] #integer location
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    69
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %%
df.reset_index(inplace = True)
df.head(5)
# Out:
#    index                                        title   industry  \
# 0      0                              Pather Panchali  Bollywood
# 1      1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2      2                        Thor: The Dark World   Hollywood
# 3      3                              Thor: Ragnarok   Hollywood
# 4      4                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating                     studio   budget   revenue  \
# 0          1955          8.3  Government of West Bengal  70000.0  100000.0
# 1          2022          7.0             Marvel Studios    200.0     954.8
# 2          2013          6.8             Marvel Studios    165.0     644.8
# 3          2017          7.9             Marvel Studios    180.0     854.0
# 4          2022          6.8             Marvel Studios    250.0     670.0
#
#         unit currency language  age   profit
# 0  Thousands      INR  Bengali   69  30000.0
# ...
